# %%
tupl=('king','queen',1,2,3,4)

# %%
print(tupl)
# Out:
# ('king', 'queen', 1, 2, 3, 4)

# %%
type(tupl)
# Out:
# tuple

# %%
x=[1,2,3,4,5]

# %%
type(x)
# Out:
# list

# %%
x=tuple(x)

# %%
type(x)
# Out:
# tuple

# %%
student={'name':'Sahil','contact':7889116517}

# %%
print(student)
# Out:
# {'name': 'Sahil', 'contact': 7889116517}

# %%
print(student['name'])
# Out:
# Sahil

# %%
student['address']='Mohali'

# %%
print(student['address'])
# Out:
# Mohali

# %%
student.update({'name':'Shiv','contact':8219705243})

# %%
print(student)
# Out:
# {'name': 'Shiv', 'contact': 8219705243, 'address': 'Mohali'}

# %%
student.pop('address')
# Out:
# 'Mohali'

# %%
print(student)
# Out:
# {'name': 'Shiv', 'contact': 8219705243}

# %%
del student['name']

# %%
print(student)
# Out:
# {'contact': 8219705243}

# %%
student.update({'subject':'data science','address':'mohali'})

# %%
print(student)
# Out:
# {'contact': 8219705243, 'subject': 'data science', 'address': 'mohali'}

# %%
print(student.get('name','name not found'))
# Out:
# name not found

# %%
print(student.get('subject','not found'))
# Out:
# data science

# %%
student={'student1':{
    'name':'Sahil',
    'roll no':852},
         'student2':{
             'name':'Rajan',
             'roll no':7412}
        }

# %%
print(student)
# Out:
# {'student1': {'name': 'Sahil', 'roll no': 852}, 'student2': {'name': 'Rajan', 'roll no': 7412}}

# %%
print(student['student1']['name'])
# Out:
# Sahil

# %%
print(len(student['student1']))
# Out:
# 2

# %%
student.keys()
# Out:
# dict_keys(['student1', 'student2'])

# %%
student.values()
# Out:
# dict_values([{'name': 'Sahil', 'roll no': 852}, {'name': 'Rajan', 'roll no': 7412}])

# %%
student.items()
# Out:
# dict_items([('student1', {'name': 'Sahil', 'roll no': 852}), ('student2', {'name': 'Rajan', 'roll no': 7412})])

# %%
'student1' in student
# Out:
# True

# %%
'Sahil' in student['student1'].values()
# Out:
# True

# %%
set1={'KING','queen','roger'}

# %%
print(set1)
# Out:
# {'queen', 'roger', 'KING'}

# %%
set1.pop()
# Out:
# 'queen'

# %%
set1.update({'King'})

# %%
set1
# Out:
# {'KING', 'King', 'roger'}

# %%
set1.update({'king'})

# %%
set1
# Out:
# {'KING', 'King', 'king', 'roger'}

# %%
list5=list(set1)

# %%
print(list5)
# Out:
# ['roger', 'king', 'King', 'KING']

# %%
type(list5)
# Out:
# list

# %%
set1.update('king')

# %%
print(set1)
# Out:
# {'n', 'k', 'i', 'roger', 'king', 'g', 'King', 'KING'}

# %%
list7=list(set1)

# %%
print(list7)
# Out:
# ['n', 'k', 'i', 'roger', 'king', 'g', 'King', 'KING']

# %%
type(list7)
# Out:
# list

# %%
#string methods

# %%
# string.upper(),string.lower(),string.capitalize(first character will become upper rest are in lower
#), stringsentence.strip()-remove blank spaces ,.replace() will replace the sentence or particular element present in the string
# count(char) give count , .join() to join the string

# %%
sent=['i','like','python']

# %%
print(" ".join(sent))
# Out:
# i like python

# %%
words='i am the king'

# %%
words.isalnum()
# Out:
# False

# %%
words.isalpha()
# Out:
# False

# %%
words.isdigit()
# Out:
# False

# %%
words.isspace()
# Out:
# False

# %%
word='king'

# %%
word.isalpha()
# Out:
# True

# %%
w='king1'

# %%
w.isalnum()
# Out:
# True
