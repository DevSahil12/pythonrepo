# %%
list=['hello','Sahil','Sharma']

# %%
print(list)
# Out:
# ['hello', 'Sahil', 'Sharma']

# %%
list.append('Shiv')

# %%
print(list)
# Out:
# ['hello', 'Sahil', 'Sharma', 'Shiv']

# %%
print(list[-2])
# Out:
# Sharma

# %%
print(list[0:3])
# Out:
# ['hello', 'Sahil', 'Sharma']

# %%
list.index('hello')
# Out:
# 0

# %%
list.count('Shiv')
# Out:
# 1

# %%
list.append('Shiv')

# %%
list.count('Shiv')
# Out:
# 2

# %%
list2=[9,8,7,6,5,4,3,2,1]

# %%
list2.sort()

# %%
print(list2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list2.sort(reverse=True)

# %%
print(list2)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
list2.append(9)

# %%
print(list2)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 9]

# %%
list.remove('hello')

# %%
print(list)
# Out:
# ['Sahil', 'Sharma', 'Shiv', 'Shiv']

# %%
list.pop(3)
# Out:
# 'Shiv'

# %%
print(list)
# Out:
# ['Sahil', 'Sharma', 'Shiv']

# %%
list.extend(list2)

# %%
print(list)
# Out:
# ['Sahil', 'Sharma', 'Shiv', 9, 8, 7, 6, 5, 4, 3, 2, 1, 9]

# %%
print(list2)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 9]

# %%
list.insert(3,'hLO')

# %%
print(list)
# Out:
# ['Sahil', 'Sharma', 'Shiv', 'hLO', 9, 8, 7, 6, 5, 4, 3, 2, 1, 9]

# %%
print(list[3][0:2])
# Out:
# hL

# %%
print(list[1][0:3])
# Out:
# Sha

# %%
print(list2)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 9]

# %%
list.insert(3,list2)

# %%
print(list)
# Out:
# ['Sahil', 'Sharma', 'Shiv', [9, 8, 7, 6, 5, 4, 3, 2, 1, 9], 'hLO', 9, 8, 7, 6, 5, 4, 3, 2, 1, 9]
