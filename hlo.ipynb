# %%
a=2

# %%
b='king'

# %%
print(str(a)+b)
# Out:
# 2king

# %%
z=3

# %%
print(int(a)+z)
# Out:
# 5

# %%
##### m=input()

# %%
print(m)
# Out:
# 50

# %%
cities='''Mohali
Landran
Chandigarh'''

# %%
print(cities)
# Out:
# Mohali
# Landran
# Chandigarh

# %%
city='mohali\nlandran'

# %%
print(city)
# Out:
# mohali
# landran

# %%
hello12=r'king\aman\ram\sham\thing' # r is raw string

# %%
print(hello12)
# Out:
# king\aman\ram\sham\thing

# %%
value='\u0927\u0928'

# %%
print(value)
# Out:
# धन
